# %%
from Shape import Shape
from Circle import Circle
from Rectangle import Rectangle
from math import pi
import inspect
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 from Shape import Shape
#       2 from Circle import Circle
# ----> 3 from Rectangle import Rectangle
#       4 from math import pi
#       5 import inspect
#
# File c:\Users\shenz\Desktop\gitrepos\nyrepo1\lab2\Rectangle.py:3
#       1 import Shape as Shape
# ----> 3 class Rectangle(Shape):
#       4     def __init__(self, x=0, y=0, width=1, length=1):
#       5         super().__init__(x,y)
#
# TypeError: module() takes at most 2 arguments (3 given)

# %% [markdown]
# circ1 = Circle(5, 2, 3)
# print(circ1)
# Shape.translate(circ1, "b", 1) #raise Typeerror
# print(circ1)

# %% [markdown]
# cookie = Shape("hds", 3)
#
# cookie

# %%
circ2 = Circle(1, 0, 0)
circ2.UnitCircleCheck()
#print(inspect.getsource(Circle))
# Out:
# created shape on x:0 y:0
# True

# %%
circ3 = Circle(4, 2, 3)
print(circ2 == circ3)
circ4 = Circle(4, 4, 6)
print(circ4 == circ3)
# Out:
# created shape on x:2 y:3
# False
# created shape on x:4 y:6
# True

# %%
print(circ2)
print(circ2.UnitCircleCheck())
circ2.translate(2, 3)
print(circ2)
print(circ2.UnitCircleCheck())
# Out:
# Circle positioned at x:0, y:0
# True
# Circle positioned at x:2, y:3
# False

# %%
print(circ2 >= circ3)
circ3 >= circ4
# Out:
# False
# True

# %%
circ5 = Circle(4, 8, 5)
circ5.translate("fff", 3)
# Out:
# created shape on x:8 y:5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 circ5 = Circle(4, 8, 5)
# ----> 2 circ5.translate("fff", 3)
#
# File c:\Users\shenz\Desktop\gitrepos\nyrepo1\lab2\Shape.py:12, in Shape.translate(self, xstep, ystep)
#      10 def translate(self, xstep, ystep):
#      11     if not isinstance(xstep, (float, int)) or not isinstance(ystep, (float, int)): # if input is not a number
# ---> 12         raise TypeError("x(x-path) and y(y-path) must be numbers")
#      13     self.x += xstep
#      14     self.y += ystep
#
# TypeError: x(x-path) and y(y-path) must be numbers

# %%
circ6 = Circle(radius=5)
print(circ6)
# Out:
# created shape on x:0 y:0
# Circle positioned at x:0, y:0
